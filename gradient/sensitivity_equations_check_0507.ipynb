# %% [markdown]
# # Check The Math Behind the dE/dp Calculations

# %%
import numpy as np
from brian2 import *
from brian2tools import *
from sympy import *
from brian2.units.fundamentalunits import DIMENSIONLESS
from tqdm import tqdm
# Out:
# WARNING    /home/alteska/anaconda3/envs/brian_opt/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
#  [py.warnings]

# %% [markdown]
# ## Senstivity to Create The new system of Equations

# %%
def get_sensitivity_equations(group, parameters):
    eqs = group.equations
    diff_eqs = eqs.get_substituted_expressions(group.variables)
    diff_eq_names = [name for name, _ in diff_eqs]

    system = Matrix([diff_eq[1] for diff_eq in diff_eqs])
    J = system.jacobian(diff_eq_names)

    sensitivity = []
    sensitivity_names = []
    for parameter in parameters:
        F = system.jacobian([parameter])
        names = ['S_{}_{}'.format(diff_eq_name, parameter)
                 for diff_eq_name in diff_eq_names]
        sensitivity.append(J * Matrix(names) + F)
        sensitivity_names.append(names)

    new_eqs = []
    for names, sensitivity_eqs, param in zip(sensitivity_names, sensitivity, parameters):
        for name, eq, orig_var in zip(names, sensitivity_eqs, diff_eq_names):
            unit = eqs[orig_var].dim / group.namespace[parameter].dim
            new_eqs.append('d{lhs}/dt = {rhs} : {unit}'.format(lhs=name,
                                                           rhs=eq,
                                                           unit=repr(unit) if unit is not DIMENSIONLESS else '1'))
    new_eqs = Equations('\n'.join(new_eqs))
    return new_eqs

# %% [markdown]
# ## Generate Sensitivity Equations for Conductivities

# %%
dt = 0.1 * ms
defaultclock.dt = dt
duration = 2*second

# %%
# Parameters
area = 20000*umetre**2
# gl = 5e-5*siemens*cm**-2 * area
# g_na = 100*msiemens*cm**-2 * area
# g_kd = 30*msiemens*cm**-2 * area
Cm = 1*ufarad*cm**-2 * area
El = -65*mV
EK = -90*mV
ENa = 50*mV
VT = -63*mV

# %%
# The model
eqs = Equations('''
dv/dt = (gl*(El-v) - g_na*(m*m*m)*h*(v-ENa) - g_kd*(n*n*n*n)*(v-EK) + I) / Cm : volt
dm/dt = 0.32*(mV**-1)*(13.*mV-v+VT)/
    (exp((13.*mV-v+VT)/(4.*mV))-1.)/ms*(1-m)-0.28*(mV**-1)*(v-VT-40.*mV)/
    (exp((v-VT-40.*mV)/(5.*mV))-1.)/ms*m : 1
dn/dt = 0.032*(mV**-1)*(15.*mV-v+VT)/
    (exp((15.*mV-v+VT)/(5.*mV))-1.)/ms*(1.-n)-.5*exp((10.*mV-v+VT)/(40.*mV))/ms*n : 1
dh/dt = 0.128*exp((17.*mV-v+VT)/(18.*mV))/ms*(1.-h)-4./(1+exp((40.*mV-v+VT)/(5.*mV)))/ms*h : 1
I: amp 
'''
)

# %%
start_scope()

# %%
group = NeuronGroup(1, eqs,
                    method='exponential_euler',
                    namespace={'gl': 5e-5*siemens*cm**-2 * area,
                              'g_na': 100*msiemens*cm**-2 * area,
                              'g_kd': 30*msiemens*cm**-2 * area})
group.I = '1*nA'
group.v = El
mon = StateMonitor(group, ['v', 'I'], record=True)

# %%
run(20*ms)

# %%
output = mon.v

# %%
plt.plot(mon.v[0]/mV);
plt.plot(mon.I[0]/nA);

# %%
new_eqs = get_sensitivity_equations(group, ['gl', 'g_na', 'g_kd'])
new_eqs
# Out:
# dS_v_gl/dt = -S_h_gl*g_na*m**3.0*(-ENa + v)/Cm - 3.0*S_m_gl*g_na*h*m**2.0*(-ENa + v)/Cm - 4.0*S_n_gl*g_kd*n**3.0*(-EK + v)/Cm + S_v_gl*(-g_kd*n**4.0 - g_na*h*m**3.0 - gl)/Cm + (El - v)/Cm : metre ** 4 * kilogram ** 2 * second ** -6 * amp ** -3
# dS_m_gl/dt = S_m_gl*(-0.32*mV**(-1.0)*(VT + 13.0*mV - v)/(ms*(exp((0.25*VT + 3.25*mV - 0.25*v)/mV) - 1.0)) - 0.28*mV**(-1.0)*(-VT - 40.0*mV + v)/(ms*(exp((-0.2*VT - 8.0*mV + 0.2*v)/mV) - 1.0))) + S_v_gl*(0.056*m*mV**(-2.0)*(exp((-0.2*VT - 8.0*mV + 0.2*v)/mV) - 1.0)**(-2.0)*(-VT - 40.0*mV + v)*exp((-0.2*VT - 8.0*mV + 0.2*v)/mV)/ms - 0.28*m*mV**(-1.0)/(ms*(exp((-0.2*VT - 8.0*mV + 0.2*v)/mV) - 1.0)) + 0.08*mV**(-2.0)*(1.0 - m)*(exp((0.25*VT + 3.25*mV - 0.25*v)/mV) - 1.0)**(-2.0)*(VT + 13.0*mV - v)*exp((0.25*VT + 3.25*mV - 0.25*v)/mV)/ms - 0.32*mV**(-1.0)*(1.0 - m)/(ms*(exp((0.25*VT + 3.25*mV - 0.25*v)/mV) - 1.0))) : ohm
# dS_n_gl/dt = S_n_gl*(-0.032*mV**(-1.0)*(VT + 15.0*mV - v)/(ms*(exp((0.2*VT + 3.0*mV - 0.2*v)/mV) - 1.0)) - 0.5*exp((0.025*VT + 0.25*mV - 0.025*v)/mV)/ms) + S_v_gl*(0.0064*mV**(-2.0)*(1.0 - n)*(exp((0.2*VT + 3.0*mV - 0.2*v)/mV) - 1.0)**(-2.0)*(VT + 15.0*mV - v)*exp((0.2*VT + 3.0*mV - 0.2*v)/mV)/ms - 0.032*mV**(-1.0)*(1.0 - n)/(ms*(exp((0.2*VT + 3.0*mV - 0.2*v)/mV) - 1.0)) + 0.0125*n*exp((0.025*VT + 0.25*mV - 0.025*v)/mV)/(mV*ms)) : ohm
# dS_h_gl/dt = S_h_gl*(-0.128*exp((0.0555555555555556*VT + 0.944444444444445*mV - 0.0555555555555556*v)/mV)/ms - 4.0/(ms*(exp((0.2*VT + 8.0*mV - 0.2*v)/mV) + 1.0))) + S_v_gl*(-0.8*h*(exp((0.2*VT + 8.0*mV - 0.2*v)/mV) + 1.0)**(-2.0)*exp((0.2*VT + 8.0*mV - 0.2*v)/mV)/(mV*ms) - (0.00711111111111112 - 0.00711111111111112*h)*exp((0.0555555555555556*VT + 0.944444444444445*mV - 0.0555555555555556*v)/mV)/(mV*ms)) : ohm
# dS_v_g_na/dt = -S_h_g_na*g_na*m**3.0*(-ENa + v)/Cm - 3.0*S_m_g_na*g_na*h*m**2.0*(-ENa + v)/Cm - 4.0*S_n_g_na*g_kd*n**3.0*(-EK + v)/Cm + S_v_g_na*(-g_kd*n**4.0 - g_na*h*m**3.0 - gl)/Cm - h*m**3.0*(-ENa + v)/Cm : metre ** 4 * kilogram ** 2 * second ** -6 * amp ** -3
# dS_m_g_na/dt = S_m_g_na*(-0.32*mV**(-1.0)*(VT + 13.0*mV - v)/(ms*(exp((0.25*VT + 3.25*mV - 0.25*v)/mV) - 1.0)) - 0.28*mV**(-1.0)*(-VT - 40.0*mV + v)/(ms*(exp((-0.2*VT - 8.0*mV + 0.2*v)/mV) - 1.0))) + S_v_g_na*(0.056*m*mV**(-2.0)*(exp((-0.2*VT - 8.0*mV + 0.2*v)/mV) - 1.0)**(-2.0)*(-VT - 40.0*mV + v)*exp((-0.2*VT - 8.0*mV + 0.2*v)/mV)/ms - 0.28*m*mV**(-1.0)/(ms*(exp((-0.2*VT - 8.0*mV + 0.2*v)/mV) - 1.0)) + 0.08*mV**(-2.0)*(1.0 - m)*(exp((0.25*VT + 3.25*mV - 0.25*v)/mV) - 1.0)**(-2.0)*(VT + 13.0*mV - v)*exp((0.25*VT + 3.25*mV - 0.25*v)/mV)/ms - 0.32*mV**(-1.0)*(1.0 - m)/(ms*(exp((0.25*VT + 3.25*mV - 0.25*v)/mV) - 1.0))) : ohm
# dS_n_g_na/dt = S_n_g_na*(-0.032*mV**(-1.0)*(VT + 15.0*mV - v)/(ms*(exp((0.2*VT + 3.0*mV - 0.2*v)/mV) - 1.0)) - 0.5*exp((0.025*VT + 0.25*mV - 0.025*v)/mV)/ms) + S_v_g_na*(0.0064*mV**(-2.0)*(1.0 - n)*(exp((0.2*VT + 3.0*mV - 0.2*v)/mV) - 1.0)**(-2.0)*(VT + 15.0*mV - v)*exp((0.2*VT + 3.0*mV - 0.2*v)/mV)/ms - 0.032*mV**(-1.0)*(1.0 - n)/(ms*(exp((0.2*VT + 3.0*mV - 0.2*v)/mV) - 1.0)) + 0.0125*n*exp((0.025*VT + 0.25*mV - 0.025*v)/mV)/(mV*ms)) : ohm
# dS_h_g_na/dt = S_h_g_na*(-0.128*exp((0.0555555555555556*VT + 0.944444444444445*mV - 0.0555555555555556*v)/mV)/ms - 4.0/(ms*(exp((0.2*VT + 8.0*mV - 0.2*v)/mV) + 1.0))) + S_v_g_na*(-0.8*h*(exp((0.2*VT + 8.0*mV - 0.2*v)/mV) + 1.0)**(-2.0)*exp((0.2*VT + 8.0*mV - 0.2*v)/mV)/(mV*ms) - (0.00711111111111112 - 0.00711111111111112*h)*exp((0.0555555555555556*VT + 0.944444444444445*mV - 0.0555555555555556*v)/mV)/(mV*ms)) : ohm
# dS_v_g_kd/dt = -S_h_g_kd*g_na*m**3.0*(-ENa + v)/Cm - 3.0*S_m_g_kd*g_na*h*m**2.0*(-ENa + v)/Cm - 4.0*S_n_g_kd*g_kd*n**3.0*(-EK + v)/Cm + S_v_g_kd*(-g_kd*n**4.0 - g_na*h*m**3.0 - gl)/Cm - n**4.0*(-EK + v)/Cm : metre ** 4 * kilogram ** 2 * second ** -6 * amp ** -3
# dS_m_g_kd/dt = S_m_g_kd*(-0.32*mV**(-1.0)*(VT + 13.0*mV - v)/(ms*(exp((0.25*VT + 3.25*mV - 0.25*v)/mV) - 1.0)) - 0.28*mV**(-1.0)*(-VT - 40.0*mV + v)/(ms*(exp((-0.2*VT - 8.0*mV + 0.2*v)/mV) - 1.0))) + S_v_g_kd*(0.056*m*mV**(-2.0)*(exp((-0.2*VT - 8.0*mV + 0.2*v)/mV) - 1.0)**(-2.0)*(-VT - 40.0*mV + v)*exp((-0.2*VT - 8.0*mV + 0.2*v)/mV)/ms - 0.28*m*mV**(-1.0)/(ms*(exp((-0.2*VT - 8.0*mV + 0.2*v)/mV) - 1.0)) + 0.08*mV**(-2.0)*(1.0 - m)*(exp((0.25*VT + 3.25*mV - 0.25*v)/mV) - 1.0)**(-2.0)*(VT + 13.0*mV - v)*exp((0.25*VT + 3.25*mV - 0.25*v)/mV)/ms - 0.32*mV**(-1.0)*(1.0 - m)/(ms*(exp((0.25*VT + 3.25*mV - 0.25*v)/mV) - 1.0))) : ohm
# dS_n_g_kd/dt = S_n_g_kd*(-0.032*mV**(-1.0)*(VT + 15.0*mV - v)/(ms*(exp((0.2*VT + 3.0*mV - 0.2*v)/mV) - 1.0)) - 0.5*exp((0.025*VT + 0.25*mV - 0.025*v)/mV)/ms) + S_v_g_kd*(0.0064*mV**(-2.0)*(1.0 - n)*(exp((0.2*VT + 3.0*mV - 0.2*v)/mV) - 1.0)**(-2.0)*(VT + 15.0*mV - v)*exp((0.2*VT + 3.0*mV - 0.2*v)/mV)/ms - 0.032*mV**(-1.0)*(1.0 - n)/(ms*(exp((0.2*VT + 3.0*mV - 0.2*v)/mV) - 1.0)) + 0.0125*n*exp((0.025*VT + 0.25*mV - 0.025*v)/mV)/(mV*ms)) : ohm
# dS_h_g_kd/dt = S_h_g_kd*(-0.128*exp((0.0555555555555556*VT + 0.944444444444445*mV - 0.0555555555555556*v)/mV)/ms - 4.0/(ms*(exp((0.2*VT + 8.0*mV - 0.2*v)/mV) + 1.0))) + S_v_g_kd*(-0.8*h*(exp((0.2*VT + 8.0*mV - 0.2*v)/mV) + 1.0)**(-2.0)*exp((0.2*VT + 8.0*mV - 0.2*v)/mV)/(mV*ms) - (0.00711111111111112 - 0.00711111111111112*h)*exp((0.0555555555555556*VT + 0.944444444444445*mV - 0.0555555555555556*v)/mV)/(mV*ms)) : ohm

# %% [markdown]
# ## Create Working Model to Plug in Variable Conductivity

# %%
# The model
eqs_fit = Equations('''
dv/dt = (gl*(El-v) - g_na*(m*m*m)*h*(v-ENa) - g_kd*(n*n*n*n)*(v-EK) + I) / Cm : volt
dm/dt = 0.32*(mV**-1)*(13.*mV-v+VT)/
    (exp((13.*mV-v+VT)/(4.*mV))-1.)/ms*(1-m)-0.28*(mV**-1)*(v-VT-40.*mV)/
    (exp((v-VT-40.*mV)/(5.*mV))-1.)/ms*m : 1
dn/dt = 0.032*(mV**-1)*(15.*mV-v+VT)/
    (exp((15.*mV-v+VT)/(5.*mV))-1.)/ms*(1.-n)-.5*exp((10.*mV-v+VT)/(40.*mV))/ms*n : 1
dh/dt = 0.128*exp((17.*mV-v+VT)/(18.*mV))/ms*(1.-h)-4./(1+exp((40.*mV-v+VT)/(5.*mV)))/ms*h : 1
I: amp 
gl: siemens(constant)
g_na: siemens(constant)
g_kd: siemens(constant)
'''
)

# %%
t_start=0*second
n_samples = 1

# %%
model = eqs_fit + new_eqs

# %%
Ntraces, Nsteps = output.shape
duration = Nsteps * dt
output_traces = TimedArray(output.transpose(), dt=dt)
output_var = 'v'

# %%
start_scope()

# %%
neurons = NeuronGroup(1, model, method='exponential_euler',)
neurons.namespace['output_var'] = output_traces
neurons.namespace['Nsteps'] = Nsteps
neurons.namespace['Ntraces'] = Ntraces
neurons.namespace['t_start'] = t_start

# %%
d_gl = 5e-5*siemens*cm**-2 * area
d_g_na = 100*msiemens*cm**-2 * area
d_g_kd = 30*msiemens*cm**-2 * area

# %%
state = {'gl': d_gl, 'g_na': d_g_na, 'g_kd': d_g_kd}
neurons.set_states(state)

# %%
neurons.I = '1*nA'
neurons.v = El
mon = StateMonitor(neurons, ['v', 'S_v_gl','S_v_g_na', 'S_v_g_kd' ], record=True)

# %%
run(20*ms)

# %%
v_trace = mon.v[0]
svgl = mon.S_v_gl[0]
svgkd = mon.S_v_g_kd[0]
svgna = mon.S_v_g_na[0]

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,5))
ax[0].plot(v_trace)
ax[1].plot(svgl)
ax[2].plot(svgkd)
ax[3].plot(svgna)

# %%
data = output[0]

E = np.sum(np.square(data - v_trace))
dEdp = np.sum(2 * svgl * data - 2 * svgl * v_trace)

# %%
print(E, dEdp)
# Out:
# 3.5031462 fV^2 -5.14913481e-08 m^6 kg^3 s^-9 A^-4

# %% [markdown]
# ## Change it into a function

# %%
def eval_neurons(params):
    
    # init neurons
    start_scope()
    neurons = NeuronGroup(1, model, method='exponential_euler',)
    neurons.namespace['output_var'] = output_traces
    neurons.namespace['Nsteps'] = Nsteps
    neurons.namespace['Ntraces'] = Ntraces
    neurons.namespace['t_start'] = t_start

    # set new parameters
    state = {'gl': params[0], 'g_na': params[1], 'g_kd': params[2]}
    neurons.set_states(state)

    # run simulation
    neurons.I = '1*nA'
    neurons.v = El
    mon = StateMonitor(neurons, ['v', 'S_v_gl','S_v_g_na', 'S_v_g_kd' ], record=True)
    run(20*ms)
    
    # get traces
    v_trace = mon.v[0]
    svgl = mon.S_v_gl[0]
    svgkd = mon.S_v_g_kd[0]
    svgna = mon.S_v_g_na[0]

    # analyze results
    dSdp = svgl # svgkd + svgna

    data = output[0]

    E = np.sum(np.square(data - v_trace))/Nsteps
#     dEdp = np.sum(2 * dSdp * (data - v_trace)) / Nsteps
    dEdp = np.sum(2 * dSdp * (v_trace - data)) / Nsteps**2

    return E, dEdp

# %%
d = [10 * nS, 20 * uS, 6 * uS]

# %%
eval_neurons(d)
# Out:
# (0.53582592 * fvolt2,
#  2.29818193e-12 * metre ** 6 * kilogram ** 3 * second ** -9 * amp ** -4)

# %% [markdown]
# ### Explore range of gl

# %% [markdown]
# #### log like behavior

# %%
inp = np.array([9.9, 9.99, 9.999, 9.9999, 9.99999, 10, 10.00001, 10.0001, 10.001, 10.01, 10.1])
len(inp)
# Out:
# 11

# %%
out, grad, est = [], [], []

for i in tqdm(inp):
    a, b = eval_neurons([i*nS, d[1], d[2]])
    dp = 10 - i
    est.append(dEdp * dp)
    out.append(a)
    grad.append(b)
# Out:
# 100%|██████████| 11/11 [00:03<00:00,  3.57it/s]

# %%
out_ = Quantity(out) / mV**2
grad_ = Quantity(grad) / (metre ** 6 * kilogram ** 3 * second ** -9 * amp ** -4)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(15, 5))
ax[0].plot(inp, out_);
ax[1].plot(inp, grad_);
ax[1].hlines(y=0, xmin=9.9, xmax = 10.1);

# %% [markdown]
# ### close to zero

# %%
# inp = np.array([10, 10.000001, 10.000002, 10.000003, 10.000004, 10.000005])
inp = np.arange(10, 10.000010, 0.000001)
len(inp)

print(inp)
# Out:
# [10.       10.000001 10.000002 10.000003 10.000004 10.000005 10.000006
#  10.000007 10.000008 10.000009]

# %%
out, grad, est = [], [], []

for i in tqdm(inp):
    E, dEdp = eval_neurons([i*nS, d[1], d[2]])
    dp = 10 - i
    est.append(dp)
    out.append(E)
    grad.append(dEdp)
# Out:
# 100%|██████████| 10/10 [00:02<00:00,  3.47it/s]

# %%
out_ = Quantity(out) / mV**2
grad_ = Quantity(grad) / (metre ** 6 * kilogram ** 3 * second ** -9 * amp ** -4)

# %%
fig, ax = plt.subplots(ncols=3, figsize=(15, 5))
ax[0].plot(inp, out_);
ax[1].plot(inp, grad_);
ax[2].plot(inp, est);

# %%
dp = est[1]
dEdp = grad[1]
E = out[1]

# %% [markdown]
# ## 5 to 15; 0.1 step

# %%
inp = np.arange(5, 15.1, 0.1)
len(inp)
# Out:
# 101

# %%
out, grad, est = [], [], []

for i in tqdm(inp):
    E, dEdp = eval_neurons([i*nS, d[1], d[2]])
    dp = 10 - i
    est.append(dp)
    out.append(E)
    grad.append(dEdp)
# Out:
# 100%|██████████| 101/101 [00:32<00:00,  3.74it/s]

# %%
out_ = Quantity(out) / mV**2
grad_ = Quantity(grad) / (metre ** 6 * kilogram ** 3 * second ** -9 * amp ** -4)

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20, 5))
ax[0].plot(inp, out_);
ax[1].plot(inp, grad_);
ax[2].plot(inp[1:], np.diff(out_)/0.1)

ax[3].plot(inp[1:], np.diff(out_)/0.1)
ax[3].plot(inp, np.array(grad_));

ax[0].set_title('E')
ax[1].set_title('dEdp')
ax[2].set_title('E/dp');

# %% [markdown]
# ## 9 to 11; 0.01 step

# %%
E
# Out:
# 17.36497403 * mvolt2

# %%
inp = np.arange(9, 11.1, 0.01)
len(inp)
# Out:
# 210

# %%
out, grad, est = [], [], []

for i in tqdm(inp):
    E, dEdp = eval_neurons([i*nS, d[1], d[2]])
    dp = 10 - i
    est.append(dp)
    out.append(E)
    grad.append(dEdp)
# Out:
# 100%|██████████| 210/210 [00:55<00:00,  3.85it/s]

# %%
out_ = Quantity(out) / mV**2
grad_ = Quantity(grad) / (metre ** 6 * kilogram ** 3 * second ** -9 * amp ** -4)

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20, 5))
ax[0].plot(inp, out_);
ax[1].plot(inp, grad_);
ax[2].plot(inp[1:], np.diff(out_)/0.01)

ax[3].plot(inp[1:], np.diff(out_)/0.01)
ax[3].plot(inp, np.array(grad_));

ax[0].set_title('E')
ax[1].set_title('dEdp')
ax[2].set_title('E/dp');
