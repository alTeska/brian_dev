# %% [markdown]
# # Build a brain model for decilitated cell

# %%
from brian2 import *
from brian2tools import *
# Out:
# WARNING    /home/alteska/anaconda3/envs/brian_opt/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
#  [py.warnings]

# %%
import numpy as np
import pandas as pd

# %%
dt = 5e-05 * second
dt
# Out:
# 50. * usecond

# %% [markdown]
# ## Load the data

# %%
df_v = pd.read_csv('decilliated_v_pos.csv')
df_ic = pd.read_csv('decilliated_ic_pos.csv')
df_inoise = pd.read_csv('decilliated_i_noise.csv')
df_wn_v = pd.read_csv('decilliated_v_noise.csv')

# %% [markdown]
# #### Get V positive

# %%
Vout = df_v.to_numpy()
Vout = Vout[:, 2:]

# %%
np.shape(Vout)
# Out:
# (20, 22400)

# %%
Vout
# Out:
# array([[-0.02864093, -0.02855869, -0.02865738, ..., -0.02867383,
#         -0.02862449, -0.02865738],
#        [-0.02885476, -0.02873963, -0.02862449, ..., -0.02609142,
#         -0.0263217 , -0.02602562],
#        [-0.02819682, -0.02829552, -0.02832841, ..., -0.02829552,
#         -0.02827907, -0.02844355],
#        ...,
#        [-0.02579534, -0.02564731, -0.02572955, ..., -0.02423274,
#         -0.02424918, -0.02433143],
#        [-0.02441367, -0.02439722, -0.02418339, ..., -0.02276882,
#         -0.02257144, -0.02270302],
#        [-0.021272  , -0.02135425, -0.02138714, ..., -0.02329517,
#         -0.02314713, -0.02311424]])

# %%
plot(Vout.transpose());

# %% [markdown]
# #### Get positive injection current

# %%
Ic = df_ic.to_numpy()
Ic = Ic[:, 1:]

# %%
plot(Ic.transpose());

# %% [markdown]
# #### Get white noise injection

# %%
Inoise = df_inoise.to_numpy()
Inoise = Inoise[:, 1:].transpose()[0]

# %%
plot(Inoise);

# %% [markdown]
# #### Get V from white noise

# %%
Vnoise = df_wn_v.to_numpy()
Vnoise = Vnoise[:, 1:].transpose()[0]

# %%
plot(Vnoise);

# %% [markdown]
# ### Concatinate the data

# %%
np.shape(Vnoise)
# Out:
# (22400,)

# %%
np.shape(Vout)
# Out:
# (20, 22400)

# %%
output = np.concatenate((Vout, [Vnoise]))
np.shape(output)
# Out:
# (21, 22400)

# %%
input_cur = np.concatenate((Ic, [Inoise]))
np.shape(input_cur)
# Out:
# (21, 22400)

# %%
plot(input_cur.transpose());

# %%
plot(output.transpose());

# %%
plot(input_cur[11:13].transpose())
# Out:
# [<matplotlib.lines.Line2D at 0x7fc27311ab38>,
#  <matplotlib.lines.Line2D at 0x7fc27311ac88>]

# %%
plot((output[11:13]/1e-3).transpose());

# %% [markdown]
# ## Build a model

# %%
model = Equations('''
dv/dt = (gL * (EL - v) + g_k*n*(Ek - v) + I(t))/C : volt
dn/dt = (1-n)*alpha - beta*n : 1

alpha = (1/(2 * kn * taun)) * ((v-Vn) / (1-exp((Vn-v)/kn))): Hz
beta = (-1/(2 * kn * taun)) * ((v-Vn) / (1-exp((v-Vn)/kn))): Hz
g_k : siemens (constant)
kn : volt (constant)
taun : second (constant)
Vn: volt (constant)
Ek: volt (constant)
''',
# C = 130*pF,
C = 300*pF,
EL = -30*mV,
gL = 1/50*1/Mohm)
# gL = 1/142*1/Mohm)

# %%
input_current0 = np.hstack([np.zeros(int(5*ms/dt)), np.ones(int(5*ms/dt)), np.zeros(int(5*ms/dt))])*nA
I = TimedArray(input_current0, dt=dt)

# %%
G = NeuronGroup(1, model, method='exponential_euler')
G.set_states({'g_k': 1, 'kn': 1, 'taun': 1, 'Vn': 1, 'Ek': 1}, units=False)
run(10*ms)

# %%
model = Equations('''
dv/dt = (gL * (EL - v) + g_k*(n**4)*(Ek - v) + I)/C : volt
dn/dt = (1-n)*alpha - beta*n : 1

alpha = (1/(2 * kn * taun)) * ((v-Vn) / (1-exp((Vn-v)/kn))): Hz
beta = (-1/(2 * kn * taun)) * ((v-Vn) / (1-exp((v-Vn)/kn))): Hz
g_k : siemens (constant)
kn : volt (constant)
taun : second (constant)
Vn: volt (constant)
Ek: volt (constant)
''',
C = 300*pF,
EL = -30*mV,
gL = 1/50*1/Mohm)

# %%
start_scope()
n_opt = NevergradOptimizer(method='DE')
# n_opt = SkoptOptimizer()
metric = MSEMetric()

res, error = fit_traces(model=model, input_var='I', output_var='v',
                        input=input_cur[11:13] * amp, output=output[11:13]/1e-3 * volt, dt=dt,
                        method='exponential_euler',
                        g_k=[10e-3*siemens, 10e2*siemens],
                        kn = [5*mV, 20*mV],
                        Vn = [-20*mV, 20*mV],
                        Ek = [-100*mV, 0*mV],
                        taun=[10e-2*ms, 100*ms],
                        param_init={'v': -30 * mV},
                        n_rounds=1, n_samples=30, optimizer=n_opt, metric=None)
# Out:
# round 0 with error 566.9563035350116
# parameters: {'Vn': 0.0050517537684412125, 'Ek': -0.07234003961286971, 'g_k': 197.77338996337897, 'taun': 0.07432027820423301, 'kn': 0.016464893181158097}

# %%
model = Equations('''
dv/dt = (gL * (EL - v) + g_k*(n**4)*(Ek - v) + I)/C : volt
dn/dt = (1-n)*alpha - beta*n : 1

alpha = (1/(2 * kn * taun)) * ((v-Vn) / (1-exp((Vn-v)/kn))): Hz
beta = (-1/(2 * kn * taun)) * ((v-Vn) / (1-exp((v-Vn)/kn))): Hz
g_k : siemens (constant)
kn : volt (constant)
taun : second (constant)
Vn: volt (constant)
Ek: volt (constant)
C: farad (constant)
EL: volt (constant)
gL: siemens (constant)
''',
# C = 300*pF,
# EL = -30*mV,
# gL = 1/50*1/Mohm
)

# %%
start_scope()
n_opt = NevergradOptimizer(method='NoisyDE')
# n_opt = SkoptOptimizer()
metric = MSEMetric()

# %%
def callback(res, errors, parameters, index):
    print('index {} errors minimum: {}'.format(index, min(errors)) )

# %%
# set_device('cpp_standalone', directory='parallel', clean=False)

# %%
res, error = fit_traces(model=model, input_var='I', output_var='v',
                        input=input_cur * amp, output=output/1e-3 * volt, dt=dt,
                        method='exponential_euler',
                        callback=callback,
                        EL=[-50*mV, -10*mV],
                        C=[100*pF, 400*pF],
                        gL=[7*nS, 20*nS],                        
                        kn=[5*mV, 20*mV],
                        Vn=[-20*mV, 20*mV],
                        Ek=[-100*mV, 0*mV],
                        g_k=[1e1*uS, 1e6*uS],
                        taun=[0.1*ms, 30*ms],
                        param_init={'v': -30 * mV},
                        n_rounds=40, n_samples=30, optimizer=n_opt, metric=None)
# Out:
# index 0 errors minimum: 584.0702577387987
# index 1 errors minimum: 584.0778808319469
# index 2 errors minimum: 583.6353684551199
# index 3 errors minimum: 583.5964189063844
# index 4 errors minimum: 583.3818148153347
# index 5 errors minimum: 583.3901179065472
# index 6 errors minimum: 583.3126481926543
# index 7 errors minimum: 583.2536652038978
# index 8 errors minimum: 583.2346134569683
# index 9 errors minimum: 583.1707112369598
# index 10 errors minimum: 583.1651020275056
# index 11 errors minimum: 583.1434558721081
# index 12 errors minimum: 583.1231336911154
# index 13 errors minimum: 583.1085669996623
# index 14 errors minimum: 583.1061901417468
# index 15 errors minimum: 583.1023949819678
# index 16 errors minimum: 583.0950958201053
# index 17 errors minimum: 583.0928239972842
# index 18 errors minimum: 583.0870988734981
# index 19 errors minimum: 583.0855775251542
# index 20 errors minimum: 583.0775127699272
# index 21 errors minimum: 583.0761863321164
# index 22 errors minimum: 583.069263581003
# index 23 errors minimum: 583.0662272171498
# index 24 errors minimum: 583.0661148932052
# index 25 errors minimum: 583.0627558110888
# index 26 errors minimum: 583.0607878911052
# index 27 errors minimum: 583.0590264711377
# index 28 errors minimum: 583.0569892843808
# index 29 errors minimum: 583.0554671554526
# index 30 errors minimum: 583.0547910348079
# index 31 errors minimum: 583.0545000988428
# index 32 errors minimum: 583.0532440878776
# index 33 errors minimum: 583.0524011836412
# index 34 errors minimum: 583.0517442285957
# index 35 errors minimum: 583.0511037922112
# index 36 errors minimum: 583.0501121515997
# index 37 errors minimum: 583.0495902170985
# index 38 errors minimum: 583.0490954477727
# index 39 errors minimum: 583.0482965869251

# %%
res
# Out:
# {'Vn': -0.019952546083523575,
#  'Ek': -0.09995316577228627,
#  'gL': 7.0855972952852215e-09,
#  'EL': -0.049569108680822746,
#  'g_k': 0.9743722029269162,
#  'taun': 0.00020010114544840966,
#  'kn': 0.01998160663972222,
#  'C': 3.9369627036286844e-10}

# %%
print('g_k', res['g_k']*siemens)
# Out:
# g_k 0.9743722 S

# %%
print('taun', res['taun']*second)
# Out:
# taun 200.10114545 us

# %%
print('Ek', res['Ek']*volt)
print('C', res['C']*farad)
print('EL', res['EL']*volt)
print('gL', res['gL']*siemens)
print('Vn', res['Vn']*volt)
print('kn', res['kn']*volt)
# Out:
# Ek -99.95316577 mV
# C 0.39369627 nF
# EL -49.56910868 mV
# gL 7.0855973 nS
# Vn -19.95254608 mV
# kn 19.98160664 mV

# %%
# visualization of the results
start_scope()
fits = generate_fits(model=model, method='exponential_euler', params=res,
                     input=input_cur * amp, input_var='I', output_var='v',
                     param_init={'v': -92 * mV},
                     dt=dt)

fits/mV
# Out:
# array([[-92.        , -91.96183441, -91.93365193, ..., -97.7495211 ,
#         -97.7495211 , -97.7495211 ],
#        [-92.        , -91.96183441, -91.93365193, ..., -97.7495211 ,
#         -97.7495211 , -97.7495211 ],
#        [-92.        , -91.96183441, -91.93365193, ..., -97.7495211 ,
#         -97.7495211 , -97.7495211 ],
#        ...,
#        [-92.        , -91.96183441, -91.93365193, ..., -97.7495211 ,
#         -97.7495211 , -97.7495211 ],
#        [-92.        , -91.96183441, -91.93365193, ..., -97.7495211 ,
#         -97.7495211 , -97.7495211 ],
#        [-92.        , -91.85534211, -91.760923  , ..., -97.46345816,
#         -97.56067696, -97.59990408]])

# %%
d = 4
plt.figure(figsize=(10,6))
plot(fits[d]/mV)
plot(output[d]/1e-3);

# %%
plt.figure(figsize=(10,6))
plot((fits/mV).transpose());

# %%
plt.figure(figsize=(10,6))
plot((output/1e-3).transpose());

# %%
plt.figure(figsize=(10,6))
plot((fits/mV*5+400).transpose());
