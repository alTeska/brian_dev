# %% [markdown]
# # Build a brain model for decilitated cell

# %%
from brian2 import *
from brian2tools import *
# Out:
# WARNING    /home/alteska/anaconda3/envs/brian_opt/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
#  [py.warnings]

# %%
import numpy as np
import pandas as pd

# %%
dt = 5e-05 * second
dt
# Out:
# 50. * usecond

# %% [markdown]
# ## Load the data

# %%
df_v = pd.read_csv('decilliated_v_pos.csv')
df_ic = pd.read_csv('decilliated_ic_pos.csv')
df_v_neg = pd.read_csv('decilliated_v_neg.csv')
df_ic_neg = pd.read_csv('decilliated_ic_neg.csv')
df_inoise = pd.read_csv('decilliated_i_noise.csv')
df_wn_v = pd.read_csv('decilliated_v_noise.csv')

# %% [markdown]
# #### Get V positive

# %%
Vout = df_v.to_numpy()
Vout = Vout[:, 2:]

# %%
Vout_neg = df_v_neg.to_numpy()
Vout_neg = Vout_neg[:, 2:]

# %%
np.shape(Vout)
# Out:
# (20, 22399)

# %%
Vout
# Out:
# array([[-0.02855869, -0.02865738, -0.02878897, ..., -0.02867383,
#         -0.02862449, -0.02865738],
#        [-0.02873963, -0.02862449, -0.02873963, ..., -0.02609142,
#         -0.0263217 , -0.02602562],
#        [-0.02829552, -0.02832841, -0.02803234, ..., -0.02829552,
#         -0.02827907, -0.02844355],
#        ...,
#        [-0.02564731, -0.02572955, -0.0257131 , ..., -0.02423274,
#         -0.02424918, -0.02433143],
#        [-0.02439722, -0.02418339, -0.02428208, ..., -0.02276882,
#         -0.02257144, -0.02270302],
#        [-0.02135425, -0.02138714, -0.02122266, ..., -0.02329517,
#         -0.02314713, -0.02311424]])

# %%
plot(Vout.transpose());

# %% [markdown]
# #### Get positive injection current

# %%
Ic = df_ic.to_numpy()
Ic = Ic[:, 1:]

# %%
Ic_neg = df_ic_neg.to_numpy()
Ic_neg = Ic_neg[:, 1:]

# %%
plot(Ic_neg.transpose());

# %% [markdown]
# #### Get white noise injection

# %%
Inoise = df_inoise.to_numpy()
Inoise = Inoise[:, 1:].transpose()[0]

# %%
plot(Inoise);

# %% [markdown]
# #### Get V from white noise

# %%
Vnoise = df_wn_v.to_numpy()
Vnoise
# Out:
# array([[ 0.00000000e+00, -2.14199251e-02],
#        [ 1.00000000e+00, -2.11783904e-02],
#        [ 2.00000000e+00, -1.81857748e-02],
#        ...,
#        [ 2.23970000e+04, -1.97739284e-02],
#        [ 2.23980000e+04, -2.02280022e-02],
#        [ 2.23990000e+04, -2.24099003e-02]])

# %%
Vnoise = Vnoise[1:, 1:].transpose()[0]
Vnoise
# Out:
# array([-0.02117839, -0.01818577, -0.01544201, ..., -0.01977393,
#        -0.020228  , -0.0224099 ])

# %%
plot(Vnoise);

# %% [markdown]
# ### Concatinate the data

# %%
np.shape(Vnoise[:10000])
# Out:
# (10000,)

# %%
np.shape(Vout[:, :10000])
# Out:
# (20, 10000)

# %%
output = np.concatenate((Vout[:, :10000], Vout_neg[:, :10000], [Vnoise[:10000]]))
np.shape(output)
# Out:
# (39, 10000)

# %%
input_cur = np.concatenate((Ic[:,:10000], Ic_neg[:, :10000], [Inoise[:10000]]))
np.shape(input_cur)
# Out:
# (39, 10000)

# %%
plot(input_cur.transpose());

# %%
plot(output.transpose());

# %% [markdown]
# ## Build a model

# %% [markdown]
# #### Test if Model Works

# %%
model = Equations('''
dv/dt = (gL * (EL - v) + g_k*n*(Ek - v) + I(t))/C : volt
dn/dt = (1-n)*alpha - beta*n : 1

alpha = (1/(2 * kn * taun)) * ((v-Vn) / (1-exp((Vn-v)/kn))): Hz
beta = (-1/(2 * kn * taun)) * ((v-Vn) / (1-exp((v-Vn)/kn))): Hz
g_k : siemens (constant)
kn : volt (constant)
taun : second (constant)
Vn: volt (constant)
Ek: volt (constant)
''',
# C = 130*pF,
C = 300*pF,
EL = -30*mV,
gL = 1/50*1/Mohm)
# gL = 1/142*1/Mohm)

# %%
input_current0 = np.hstack([np.zeros(int(5*ms/dt)), np.ones(int(5*ms/dt)), np.zeros(int(5*ms/dt))])*nA
I = TimedArray(input_current0, dt=dt)

# %%
G = NeuronGroup(1, model, method='exponential_euler')
G.set_states({'g_k': 1, 'kn': 1, 'taun': 1, 'Vn': 1, 'Ek': 1}, units=False)
run(10*ms)

# %% [markdown]
# ## Run Model Fitting

# %%
model = Equations('''
dv/dt = (gL * (EL - v) + g_k*(n**4)*(Ek - v) + I)/C : volt
dn/dt = (1-n)*alpha - beta*n : 1

alpha = (1/(2 * kn * taun)) * ((v-Vn) / (1-exp((Vn-v)/kn))): Hz
beta = (-1/(2 * kn * taun)) * ((v-Vn) / (1-exp((v-Vn)/kn))): Hz
g_k : siemens (constant)
kn : volt (constant)
taun : second (constant)
Vn: volt (constant)
Ek: volt (constant)
C: farad (constant)
EL: volt (constant)
gL: siemens (constant)
''',
)

# %%
start_scope()
n_opt = NevergradOptimizer(method='DE')
metric = MSEMetric()

# %%
def callback(res, errors, parameters, index):
    print('index {} errors minimum: {}'.format(index, min(errors)) )

# %%
# set_device('cpp_standalone', directory='parallel', clean=False)

# %%
res, error = fit_traces(model=model, input_var='I', output_var='v',
                        input=input_cur * amp, output=output * volt, dt=dt,
                        method='exponential_euler',
                        callback=callback,
                        EL=[-50*mV, -10*mV],
                        C=[100*pF, 400*pF],
                        gL=[7*nS, 20*nS],                        
                        kn=[5*mV, 20*mV],
                        Vn=[-20*mV, 20*mV],
                        Ek=[-100*mV, 0*mV],
                        g_k=[1e-2*uS, 1e4*uS],
                        taun=[0.1*ms, 40*ms],
                        param_init={'v': -30 * mV},
                        n_rounds=40, n_samples=30, optimizer=n_opt, metric=None)
# Out:
# index 0 errors minimum: 0.0004207850286928309
# index 1 errors minimum: 0.00022378142296141615
# index 2 errors minimum: 0.00022075014767715723
# index 3 errors minimum: 0.0002082372526275171
# index 4 errors minimum: 0.00018106643351466502
# index 5 errors minimum: 0.0001713697072393565
# index 6 errors minimum: 0.00017449396300277706
# index 7 errors minimum: 0.00016368486045921786
# index 8 errors minimum: 0.00015966816140214292
# index 9 errors minimum: 0.00015636457753703765
# index 10 errors minimum: 0.0001523725240030411
# index 11 errors minimum: 0.00014953962942753843
# index 12 errors minimum: 0.00014842490296249473
# index 13 errors minimum: 0.0001472237183308764
# index 14 errors minimum: 0.0001460744387213345
# index 15 errors minimum: 0.00014524559043854033
# index 16 errors minimum: 0.0001443286657721515
# index 17 errors minimum: 0.00014409496196493793
# index 18 errors minimum: 0.00014401749505081723
# index 19 errors minimum: 0.00014336666019793657
# index 20 errors minimum: 0.0001430065284925896
# index 21 errors minimum: 0.0001436978114728486
# index 22 errors minimum: 0.0001429493071328717
# index 23 errors minimum: 0.00014327064141930805
# index 24 errors minimum: 0.0001430500432989871
# index 25 errors minimum: 0.00014284387015331407
# index 26 errors minimum: 0.00014288032161140338
# index 27 errors minimum: 0.00014297575327692648
# index 28 errors minimum: 0.0001429984366452032
# index 29 errors minimum: 0.00014277343076673861
# index 30 errors minimum: 0.000143331480761065
# index 31 errors minimum: 0.00014261823309967748
# index 32 errors minimum: 0.00014298849319628175

# %% [markdown]
# ## Print results

# %%
res

# %%
print('g_k', res['g_k']*siemens)
print('taun', res['taun']*second)

# %%
print('Ek', res['Ek']*volt)
print('C', res['C']*farad)
print('EL', res['EL']*volt)
print('gL', res['gL']*siemens)
print('Vn', res['Vn']*volt)
print('kn', res['kn']*volt)

# %% [markdown]
# ## visualization of the results

# %%
start_scope()
fits = generate_fits(model=model, method='exponential_euler', params=res,
                     input=input_cur * amp, input_var='I', output_var='v',
                     param_init={'v': -30 * mV},
                     dt=dt)

fits/mV

# %%
plt.figure(figsize=(10,6))
plot((output/1e-3).transpose());

# %%
plt.figure(figsize=(10,6))
plot((fits/mV).transpose());

# %%
plt.figure(figsize=(20,10))
# plt.ylim(-10,40)
plt.xlim(0,3000)
plot((output[11]/1e-3).transpose());
plot((fits[11]/mV).transpose());
