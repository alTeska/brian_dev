# %% [markdown]
# # Build a brain model for decilitated cell

# %%
from brian2 import *
from brian2tools import *
# Out:
# WARNING    /home/alteska/anaconda3/envs/brian_opt/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
#  [py.warnings]

# %%
import numpy as np
import pandas as pd

# %%
dt = 5e-05 * second
dt
# Out:
# 50. * usecond

# %% [markdown]
# ## Load the data

# %%
df_v = pd.read_csv('decilliated_v_pos.csv')
df_ic = pd.read_csv('decilliated_ic_pos.csv')
df_v_neg = pd.read_csv('decilliated_v_neg.csv')
df_ic_neg = pd.read_csv('decilliated_ic_neg.csv')
df_inoise = pd.read_csv('decilliated_i_noise.csv')
df_wn_v = pd.read_csv('decilliated_v_noise.csv')

# %% [markdown]
# #### Get V positive

# %%
Vout = df_v.to_numpy()
Vout = Vout[:, 2:]

# %%
Vout_neg = df_v_neg.to_numpy()
Vout_neg = Vout_neg[:, 2:]

# %%
np.shape(Vout)
# Out:
# (20, 22399)

# %%
Vout
# Out:
# array([[-0.02855869, -0.02865738, -0.02878897, ..., -0.02867383,
#         -0.02862449, -0.02865738],
#        [-0.02873963, -0.02862449, -0.02873963, ..., -0.02609142,
#         -0.0263217 , -0.02602562],
#        [-0.02829552, -0.02832841, -0.02803234, ..., -0.02829552,
#         -0.02827907, -0.02844355],
#        ...,
#        [-0.02564731, -0.02572955, -0.0257131 , ..., -0.02423274,
#         -0.02424918, -0.02433143],
#        [-0.02439722, -0.02418339, -0.02428208, ..., -0.02276882,
#         -0.02257144, -0.02270302],
#        [-0.02135425, -0.02138714, -0.02122266, ..., -0.02329517,
#         -0.02314713, -0.02311424]])

# %%
plot(Vout.transpose());

# %% [markdown]
# #### Get positive injection current

# %%
Ic = df_ic.to_numpy()
Ic = Ic[:, 1:]

# %%
Ic_neg = df_ic_neg.to_numpy()
Ic_neg = Ic_neg[:, 1:]

# %%
plot(Ic_neg.transpose());

# %% [markdown]
# #### Get white noise injection

# %%
Inoise = df_inoise.to_numpy()
Inoise = Inoise[:, 1:].transpose()[0]

# %%
plot(Inoise);

# %% [markdown]
# #### Get V from white noise

# %%
Vnoise = df_wn_v.to_numpy()
Vnoise
# Out:
# array([[ 0.00000000e+00, -2.14081728e-02],
#        [ 1.00000000e+00, -2.10647698e-02],
#        [ 2.00000000e+00, -2.10069187e-02],
#        ...,
#        [ 2.23970000e+04, -2.03119314e-02],
#        [ 2.23980000e+04, -2.02460463e-02],
#        [ 2.23990000e+04, -2.02373086e-02]])

# %%
Vnoise = Vnoise[1:, 1:].transpose()[0]
Vnoise
# Out:
# array([-0.02106477, -0.02100692, -0.02103433, ..., -0.02031193,
#        -0.02024605, -0.02023731])

# %%
plot(Vnoise);

# %% [markdown]
# ### Concatinate the data

# %%
np.shape(Vnoise[:10000])
# Out:
# (10000,)

# %%
np.shape(Vout[:, :10000])
# Out:
# (20, 10000)

# %%
output = np.concatenate((Vout[:, :10000], Vout_neg[:, :10000], [Vnoise[:10000]]))
np.shape(output)
# Out:
# (39, 10000)

# %%
input_cur = np.concatenate((Ic[:,:10000], Ic_neg[:, :10000], [Inoise[:10000]]))
np.shape(input_cur)
# Out:
# (39, 10000)

# %%
plot(input_cur.transpose());

# %%
plot(output.transpose());

# %% [markdown]
# ## Build a model

# %% [markdown]
# #### Test if Model Works

# %%
model = Equations('''
dv/dt = (gL * (EL - v) + g_k*n*(Ek - v) + I(t))/C : volt
dn/dt = (1-n)*alpha - beta*n : 1

alpha = (1/(2 * kn * taun)) * ((v-Vn) / (1-exp((Vn-v)/kn))): Hz
beta = (-1/(2 * kn * taun)) * ((v-Vn) / (1-exp((v-Vn)/kn))): Hz
g_k : siemens (constant)
kn : volt (constant)
taun : second (constant)
Vn: volt (constant)
Ek: volt (constant)
''',
C = 300*pF,
EL = -30*mV,
gL = 1/50*1/Mohm)

# %%
input_current0 = np.hstack([np.zeros(int(5*ms/dt)), np.ones(int(5*ms/dt)), np.zeros(int(5*ms/dt))])*nA
I = TimedArray(input_current0, dt=dt)

# %%
G = NeuronGroup(1, model, method='exponential_euler')
G.set_states({'g_k': 1, 'kn': 1, 'taun': 1, 'Vn': 1, 'Ek': 1}, units=False)
run(10*ms)

# %% [markdown]
# ## Run Model Fitting

# %%
model = Equations('''
dv/dt = (gL * (EL - v) + g_k*(n**4)*(Ek - v) + I)/C : volt
dn/dt = (1-n)*alpha - beta*n : 1

alpha = (1/(2 * kn * taun)) * ((v-Vn) / (1-exp((Vn-v)/kn))): Hz
beta = (-1/(2 * kn * taun)) * ((v-Vn) / (1-exp((v-Vn)/kn))): Hz
g_k : siemens (constant)
kn : volt (constant)
taun : second (constant)
Vn: volt (constant)
Ek: volt (constant)
C: farad (constant)
EL: volt (constant)
gL: siemens (constant)
''',
)

# %%
start_scope()
n_opt = NevergradOptimizer(method='DE')
metric = MSEMetric()

# %%
def callback(res, errors, parameters, index):
    print('index {} errors minimum: {}'.format(index, min(errors)) )

# %%
res, error = fit_traces(model=model, input_var='I', output_var='v',
                        input=input_cur * amp, output=output * volt, dt=dt,
                        method='exponential_euler',
                        callback=callback,
                        EL=[-50*mV, -10*mV],
                        C=[100*pF, 400*pF],
                        gL=[7*nS, 20*nS],                        
                        kn=[5*mV, 20*mV],
                        Vn=[-20*mV, 20*mV],
                        Ek=[-100*mV, 0*mV],
                        g_k=[1e-2*uS, 1e4*uS],
                        taun=[0.1*ms, 40*ms],
                        param_init={'v': -30 * mV},
                        n_rounds=40, n_samples=30, optimizer=n_opt, metric=None)
# Out:
# index 0 errors minimum: 0.0006073863158587803
# index 1 errors minimum: 0.0004917287993405721
# index 2 errors minimum: 0.0003721697515302218
# index 3 errors minimum: 0.0002714492425783486
# index 4 errors minimum: 0.00024853818748273753
# index 5 errors minimum: 0.0002181637806799631
# index 6 errors minimum: 0.0001861946287619253
# index 7 errors minimum: 0.00017309977489213596
# index 8 errors minimum: 0.00016653323141286813
# index 9 errors minimum: 0.000167103407485052
# index 10 errors minimum: 0.00016364092597164815
# index 11 errors minimum: 0.00016155371210157334
# index 12 errors minimum: 0.00015583648687382732
# index 13 errors minimum: 0.0001573948705443469
# index 14 errors minimum: 0.00015608894444831838
# index 15 errors minimum: 0.00015843635551967563
# index 16 errors minimum: 0.0001559612533844514
# index 17 errors minimum: 0.00015933708718802973
# index 18 errors minimum: 0.00016040111592479077
# index 19 errors minimum: 0.00015459441995861961
# index 20 errors minimum: 0.00015449546721550794
# index 21 errors minimum: 0.0001556210872298514
# index 22 errors minimum: 0.00015376608539242938
# index 23 errors minimum: 0.00015307647259002756
# index 24 errors minimum: 0.0001530287183387748
# index 25 errors minimum: 0.00015182433389398167
# index 26 errors minimum: 0.00015092910721900725
# index 27 errors minimum: 0.00015314392721830266
# index 28 errors minimum: 0.00015268868624828771
# index 29 errors minimum: 0.00015384338843344356
# index 30 errors minimum: 0.00015085365924515695
# index 31 errors minimum: 0.00015384503904729548
# index 32 errors minimum: 0.00015116040889900925
# index 33 errors minimum: 0.00015098490014126678
# index 34 errors minimum: 0.00015228566709998302
# index 35 errors minimum: 0.00015128091017017087
# index 36 errors minimum: 0.00015430907698009858
# index 37 errors minimum: 0.00015264370133587771
# index 38 errors minimum: 0.00015225579457688352
# index 39 errors minimum: 0.00015400619891532758

# %% [markdown]
# ## Print results

# %%
res
# Out:
# {'Ek': -0.01736472523978009,
#  'Vn': 0.01934005589663826,
#  'taun': 0.03842224076526349,
#  'gL': 1.982814360334559e-08,
#  'g_k': 0.0013875704946653181,
#  'EL': -0.01910908454587261,
#  'C': 1.17302815050589e-10,
#  'kn': 0.006074035939230508}

# %%
print('g_k', res['g_k']*siemens)
print('taun', res['taun']*second)
# Out:
# g_k 1.38757049 mS
# taun 38.42224077 ms

# %%
print('Ek', res['Ek']*volt)
print('C', res['C']*farad)
print('EL', res['EL']*volt)
print('gL', res['gL']*siemens)
print('Vn', res['Vn']*volt)
print('kn', res['kn']*volt)
# Out:
# Ek -17.36472524 mV
# C 117.30281505 pF
# EL -19.10908455 mV
# gL 19.8281436 nS
# Vn 19.3400559 mV
# kn 6.07403594 mV

# %% [markdown]
# ## visualization of the results

# %%
start_scope()
fits = generate_fits(model=model, method='exponential_euler', params=res,
                     input=input_cur * amp, input_var='I', output_var='v',
                     param_init={'v': -30 * mV},
                     dt=dt)

fits/mV
# Out:
# array([[-30.        , -29.90834123, -29.81745386, ..., -19.10908332,
#         -19.10908332, -19.10908332],
#        [-30.        , -29.90834123, -29.81745386, ..., -19.10908332,
#         -19.10908332, -19.10908332],
#        [-30.        , -29.90834123, -29.81745386, ..., -19.10908332,
#         -19.10908332, -19.10908332],
#        ...,
#        [-30.        , -29.90834123, -29.81745386, ..., -19.10908332,
#         -19.10908332, -19.10908332],
#        [-30.        , -29.90834123, -29.81745386, ..., -19.10908332,
#         -19.10908332, -19.10908332],
#        [-30.        , -29.5522736 , -29.24201369, ..., -19.55739993,
#         -19.71495522, -19.33916256]])

# %%
plt.figure(figsize=(10,6))
plot((output/1e-3).transpose());

# %%
plt.figure(figsize=(10,6))
plot((fits/mV).transpose());

# %%
plt.figure(figsize=(20,10))
# plt.ylim(-10,40)
plt.xlim(0,3000)
plot((output[11]/1e-3).transpose());
plot((fits[11]/mV).transpose());

# %%
d=25
plt.figure(figsize=(20,10))
# plt.ylim(-10,40)
plt.xlim(0,3000)
plot((output[d]/1e-3).transpose());
plot((fits[d]/mV).transpose());
